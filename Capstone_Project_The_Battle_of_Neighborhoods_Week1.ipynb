# %% [markdown]
# # Peer-graded Assignment: Capstone Project

# %% [markdown]
# # The Battle of Neighborhoods (Week 1)

# %% [markdown]
# ## Introduction/Business Problem

# %% [markdown]
# In this project I will try to find what is the __best metro station__ to stop if I want to go for an __ice cream__  and then either enjoy the sun in a nice __outdoor space__ or a instead go to a __museum__, in __Lisbon__, __Portugal__.
#
# Because I may be limited in terms of FourSquare quota, I only want to check the __red__ and __green__ lines.

# %% [markdown]
# ## Data

# %% [markdown]
# ### Libraries

# %% [markdown]
# A number of libraries will be needed in this project.

# %%
import numpy as np # library for vectorized computation
import pandas as pd # library to process data as dataframes
import folium
import requests
import json # library to handle JSON files
print('Libraries imported.')
# Out:
# Libraries imported.

# %% [markdown]
# ### Lisbon Metro Stations

# %% [markdown]
# Lisbon Metro has 4 lines (Green, Blue, Yellow and Red) and 50 stations, 6 of them being double stations for two lines:
# 1. Alameda (Red and Green Line)
# 2. Marques de Pombal (Blue and Yellow Line)
# 3. Campo Grande (Green and Yellow Line)
# 4. Baixa-Chiado (Blue and Green Line)
# 5. Sao Sebastiao (Blue and Red Line)
# 6. Saldanha (Red And Yellow Line)

# %% [markdown]
# Let's import the coordinates of all of the stations (csv file in my github area).

# %%
url = "https://raw.githubusercontent.com/AnaMariaAnaMaria/Coursera_Capstone/master/MetroLx.csv"
headers = ["Abbrevation","Name","Line","Latitude","Longitude"]
coordinates = pd.read_csv(url,names = headers,skiprows=1)
coordinates
# Out:
#    Abbrevation                   Name    Line   Latitude  Longitude
# 0           AE                Areeiro   green  38.742222  -9.134167
# 1           AF             Alfornelos    blue  38.760278  -9.205000
# 2           AH       Alto dos Moinhos    blue  38.749444  -9.179444
# 3           AL               Alvalade   green  38.753333  -9.143889
# 4           AM                Alameda   green  38.736667  -9.133889
# 5           AM                Alameda     red  38.736667  -9.133889
# 6           AN                  Anjos   green  38.726111  -9.134722
# 7           AP              Aeroporto     red  38.768611  -9.128611
# 8           AR                Arroios   green  38.733056  -9.133889
# 9           AS           Amadora Este    blue  38.757778  -9.218056
# 10          AV                Avenida    blue  38.720000  -9.145833
# 11          AX             Ameixoeira  yellow  38.779167  -9.160000
# 12          BC           Baixa-Chiado    blue  38.710556  -9.139444
# 13          BC           Baixa-Chiado   green  38.710556  -9.139444
# 14          BV             Bela Vista     red  38.746667  -9.116944
# 15          CA                Carnide    blue  38.758611  -9.192500
# 16          CG           Campo Grande  yellow  38.760000  -9.157778
# 17          CG           Campo Grande   green  38.760000  -9.157778
# 18          CH                 Chelas     red  38.754167  -9.113611
# 19          CM  Colegio Militar / Luz    blue  38.752500  -9.188611
# 20          CP          Campo Pequeno  yellow  38.741389  -9.146667
# 21          CR             Cabo Ruivo     red  38.762500  -9.103889
# 22          CS          Cais do Sodre   green  38.705278  -9.142500
# 23          CU   Cidade Universitaria  yellow  38.751667  -9.158611
# 24          EC           Entre Campos  yellow  38.747778  -9.148611
# 25          EN             Encarnacao     red  38.775278  -9.116111
# 26          IN             Intendente   green  38.722500  -9.135000
# 27          JZ       Jardim Zoologico    blue  38.741944  -9.168611
# 28          LA            Laranjeiras    blue  38.748056  -9.171944
# 29          LU                 Lumiar  yellow  38.772778  -9.159722
# 30          MM           Martim Moniz   green  38.716944  -9.135556
# 31          MO              Moscavide     red  38.775000  -9.102500
# 32          MP      Marques de Pombal  yellow  38.724167  -9.149167
# 33          MP      Marques de Pombal    blue  38.724167  -9.149167
# 34          OD               Odivelas  yellow  38.793056  -9.172778
# 35          OL                 Olaias     red  38.739167  -9.123889
# 36          OR                Oriente     red  38.767222  -9.100278
# 37          OS                Olivais     red  38.760000  -9.112222
# 38          PA                 Parque    blue  38.729167  -9.150000
# 39          PE       Praca de Espanha    blue  38.737222  -9.159444
# 40          PI                 Picoas  yellow  38.730833  -9.146944
# 41          PO               Pontinha    blue  38.761389  -9.196667
# 42          QC     Quinta das Conchas  yellow  38.766944  -9.155556
# 43          RA                   Rato  yellow  38.719722  -9.155556
# 44          RB              Reboleira    blue  38.752222  -9.224722
# 45          RE          Restauradores    blue  38.715000  -9.141389
# 46          RM                   Roma   green  38.748889  -9.141389
# 47          RO                 Rossio   green  38.713611  -9.138056
# 48          SA               Saldanha  yellow  38.735000  -9.145000
# 49          SA               Saldanha     red  38.735278  -9.144167
# 50          SP         Santa Apolonia    blue  38.712500  -9.123333
# 51          SR         Senhor Roubado  yellow  38.785556  -9.171111
# 52          SS          Sao Sebastiao    blue  38.734167  -9.153611
# 53          SS          Sao Sebastiao     red  38.735000  -9.152222
# 54          TE              Telheiras   green  38.760556  -9.165000
# 55          TP       Terreiro do Paco    blue  38.706389  -9.135278

# %% [markdown]
# Let's create a map of Lisbon with all of the stations and their respective line (colour).
# Please note that if the map is not visible, it can also be seen in https://github.com/AnaMariaAnaMaria/Coursera_Capstone/blob/master/LisbonMetroStations.JPG.

# %%
#lisbon coordinates:
lx_lat = 38.736946
lx_long = -9.142685

# create map
map_lx = folium.Map(location=[lx_lat, lx_long], zoom_start=12)

# add markers to the map
for lat, lon, poi, line in zip(coordinates['Latitude'], coordinates['Longitude'],coordinates['Name'],coordinates['Line']):
    label = folium.Popup(str(poi)+' ('+str(line)+' line)' , parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=line,
        fill=True,
        fill_color=line,
        fill_opacity=0.7).add_to(map_lx)

map_lx
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Because I may be limited in terms of FourSquare quota, I am just going to be looking at the __Red__ and __Green__ lines.

# %%
two_lines = coordinates[coordinates.Line != 'blue']
two_lines = two_lines[two_lines.Line != 'yellow']
two_lines
# Out:
#    Abbrevation           Name   Line   Latitude  Longitude
# 0           AE        Areeiro  green  38.742222  -9.134167
# 3           AL       Alvalade  green  38.753333  -9.143889
# 4           AM        Alameda  green  38.736667  -9.133889
# 5           AM        Alameda    red  38.736667  -9.133889
# 6           AN          Anjos  green  38.726111  -9.134722
# 7           AP      Aeroporto    red  38.768611  -9.128611
# 8           AR        Arroios  green  38.733056  -9.133889
# 13          BC   Baixa-Chiado  green  38.710556  -9.139444
# 14          BV     Bela Vista    red  38.746667  -9.116944
# 17          CG   Campo Grande  green  38.760000  -9.157778
# 18          CH         Chelas    red  38.754167  -9.113611
# 21          CR     Cabo Ruivo    red  38.762500  -9.103889
# 22          CS  Cais do Sodre  green  38.705278  -9.142500
# 25          EN     Encarnacao    red  38.775278  -9.116111
# 26          IN     Intendente  green  38.722500  -9.135000
# 30          MM   Martim Moniz  green  38.716944  -9.135556
# 31          MO      Moscavide    red  38.775000  -9.102500
# 35          OL         Olaias    red  38.739167  -9.123889
# 36          OR        Oriente    red  38.767222  -9.100278
# 37          OS        Olivais    red  38.760000  -9.112222
# 46          RM           Roma  green  38.748889  -9.141389
# 47          RO         Rossio  green  38.713611  -9.138056
# 49          SA       Saldanha    red  38.735278  -9.144167
# 53          SS  Sao Sebastiao    red  38.735000  -9.152222
# 54          TE      Telheiras  green  38.760556  -9.165000

# %% [markdown]
# #### Finding Venues in FourSquare

# %% [markdown]
# Let's use FourSquare to find what venues exist near each green or red line station.

# %% [markdown]
# My credentials are loaded from a json file.

# %%
#credentials as per suggestion in https://www.coursera.org/learn/applied-data-science-capstone/discussions/weeks/3/threads/VCjKK35VEemkuBJz3kVAHA
secrets = json.load(open('secrets.json'))
CLIENT_ID = secrets['CLIENT_ID']
CLIENT_SECRET = secrets['CLIENT_SECRET']
VERSION = secrets['VERSION']

print('Credentials loaded')
# Out:
# Credentials loaded

# %% [markdown]
# I am only interested in specific categories (from https://developer.foursquare.com/docs/resources/categories):

# %%
venues_cat = [
 '4bf58dd8d48988d1c9941735' # Ice Cream Shop
,'4bf58dd8d48988d165941735' # Scenic Lookout
,'4bf58dd8d48988d15a941735' # Garden
,'4bf58dd8d48988d163941735' # Park
,'4bf58dd8d48988d1e2931735' # Art Gallery
,'4bf58dd8d48988d190941735' # History Museum
,'4bf58dd8d48988d18f941735' # Art Museum
,'4fceea171983d5d06c3e9823' # Aquarium
,'50aaa49e4b90af0d42d5de11' # Castle
,'4bf58dd8d48988d191941735' # Science Museum
,'4bf58dd8d48988d15b941735' # Farm
,'4bf58dd8d48988d166941735' # Sculpture Garden
,'56aa371be4b08b9a8d5734db' # Amphitheater
,'4bf58dd8d48988d1e2941735' # Beach
,'4bf58dd8d48988d181941735' # Museum
]

# %%
# adapted function that extracts nearby venues from the lab week 3
def getNearbyVenues(names, latitudes, longitudes, radius=1000,LIMIT=100):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['id'],
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Metro Station', 
                  'Metro Station Latitude', 
                  'Metro Station Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category Id',
                  'Venue Category']
    
    return(nearby_venues)

# %%
lx_venues = getNearbyVenues(names=two_lines['Name'],
                                   latitudes=two_lines['Latitude'],
                                   longitudes=two_lines['Longitude']
                                  )
# Out:
# Areeiro
# Alvalade
# Alameda
# Alameda
# Anjos
# Aeroporto
# Arroios
# Baixa-Chiado
# Bela Vista
# Campo Grande
# Chelas
# Cabo Ruivo
# Cais do Sodre
# Encarnacao
# Intendente
# Martim Moniz
# Moscavide
# Olaias
# Oriente
# Olivais
# Roma
# Rossio
# Saldanha
# Sao Sebastiao
# Telheiras

# %% [markdown]
# Let's save the list into a csv file.

# %%
lx_venues.to_csv('test.csv', sep='\t', encoding='utf-8')

# %% [markdown]
# The list of venues has 2,103 elements.

# %%
lx_venues.shape
# Out:
# (2103, 8)

# %% [markdown]
# I am only interested in the categories mentioned above - venues_cat.
#
# There are 147 venues in these categories.

# %%
lx_venues_new = lx_venues[lx_venues['Venue Category Id'].isin(venues_cat)]
lx_venues_new.shape
# Out:
# (147, 8)

# %%
lx_venues_new
# Out:
#       Metro Station  Metro Station Latitude  Metro Station Longitude  \
# 0           Areeiro               38.742222                -9.134167
# 2           Areeiro               38.742222                -9.134167
# 6           Areeiro               38.742222                -9.134167
# 11          Areeiro               38.742222                -9.134167
# 24          Areeiro               38.742222                -9.134167
# 37          Areeiro               38.742222                -9.134167
# 51          Areeiro               38.742222                -9.134167
# 61          Areeiro               38.742222                -9.134167
# 100        Alvalade               38.753333                -9.143889
# 143        Alvalade               38.753333                -9.143889
# 200         Alameda               38.736667                -9.133889
# 217         Alameda               38.736667                -9.133889
# 226         Alameda               38.736667                -9.133889
# 234         Alameda               38.736667                -9.133889
# 235         Alameda               38.736667                -9.133889
# 238         Alameda               38.736667                -9.133889
# 243         Alameda               38.736667                -9.133889
# 245         Alameda               38.736667                -9.133889
# 283         Alameda               38.736667                -9.133889
# 300         Alameda               38.736667                -9.133889
# 317         Alameda               38.736667                -9.133889
# 326         Alameda               38.736667                -9.133889
# 334         Alameda               38.736667                -9.133889
# 335         Alameda               38.736667                -9.133889
# 338         Alameda               38.736667                -9.133889
# 343         Alameda               38.736667                -9.133889
# 345         Alameda               38.736667                -9.133889
# 383         Alameda               38.736667                -9.133889
# 401           Anjos               38.726111                -9.134722
# 419           Anjos               38.726111                -9.134722
# ...             ...                     ...                      ...
# 1741         Rossio               38.713611                -9.138056
# 1751         Rossio               38.713611                -9.138056
# 1761         Rossio               38.713611                -9.138056
# 1769         Rossio               38.713611                -9.138056
# 1774         Rossio               38.713611                -9.138056
# 1795         Rossio               38.713611                -9.138056
# 1800         Rossio               38.713611                -9.138056
# 1805         Rossio               38.713611                -9.138056
# 1834       Saldanha               38.735278                -9.144167
# 1838       Saldanha               38.735278                -9.144167
# 1874       Saldanha               38.735278                -9.144167
# 1879       Saldanha               38.735278                -9.144167
# 1892       Saldanha               38.735278                -9.144167
# 1906       Saldanha               38.735278                -9.144167
# 1917  Sao Sebastiao               38.735000                -9.152222
# 1923  Sao Sebastiao               38.735000                -9.152222
# 1924  Sao Sebastiao               38.735000                -9.152222
# 1925  Sao Sebastiao               38.735000                -9.152222
# 1943  Sao Sebastiao               38.735000                -9.152222
# 1953  Sao Sebastiao               38.735000                -9.152222
# 1965  Sao Sebastiao               38.735000                -9.152222
# 1971  Sao Sebastiao               38.735000                -9.152222
# 1973  Sao Sebastiao               38.735000                -9.152222
# 2009  Sao Sebastiao               38.735000                -9.152222
# 2016      Telheiras               38.760556                -9.165000
# 2023      Telheiras               38.760556                -9.165000
# 2036      Telheiras               38.760556                -9.165000
# 2082      Telheiras               38.760556                -9.165000
# 2084      Telheiras               38.760556                -9.165000
# 2092      Telheiras               38.760556                -9.165000
#
#                                                   Venue  Venue Latitude  \
# 0            FIB - il vero gelato italiano (geladosfib)       38.744250
# 2                                 Jardim Fernando Pessa       38.743069
# 6                              Parque da Fonte Luminosa       38.737068
# 11                                       Casa do Gelado       38.744872
# 24                                           Culturgest       38.740828
# 37                                         Surf Gelados       38.739372
# 51                                           La Fabrica       38.736899
# 61                               Jardim do Arco do Cego       38.735908
# 100                                  Gelados Conchanata       38.753678
# 143                              Jardim do Campo Grande       38.756770
# 200                            Parque da Fonte Luminosa       38.737068
# 217                        Miradouro da Penha de França       38.730900
# 226                               Jardim Fernando Pessa       38.743069
# 234                                          La Fabrica       38.736899
# 235                                        Surf Gelados       38.739372
# 238          FIB - il vero gelato italiano (geladosfib)       38.744250
# 243                              Jardim do Arco do Cego       38.735908
# 245                                          Culturgest       38.740828
# 283                                  Jardim Constantino       38.731012
# 300                            Parque da Fonte Luminosa       38.737068
# 317                        Miradouro da Penha de França       38.730900
# 326                               Jardim Fernando Pessa       38.743069
# 334                                          La Fabrica       38.736899
# 335                                        Surf Gelados       38.739372
# 338          FIB - il vero gelato italiano (geladosfib)       38.744250
# 343                              Jardim do Arco do Cego       38.735908
# 345                                          Culturgest       38.740828
# 383                                  Jardim Constantino       38.731012
# 401                            Miradouro do Monte Agudo       38.726119
# 419                                  Mú Gelato Italiano       38.722395
# ...                                                 ...             ...
# 1741                        Museu Arqueológico do Carmo       38.711980
# 1751                                     Amorino Chiado       38.710808
# 1761                  Miradouro do Castelo de São Jorge       38.712525
# 1769                                               Grom       38.710913
# 1774                               Castelo de São Jorge       38.712480
# 1795                                          Fragoleto       38.709725
# 1800                Miradouro de São Pedro de Alcântara       38.715233
# 1805                                     Gelato Therapy       38.710149
# 1834                             Jardim do Arco do Cego       38.735908
# 1838                                         La Fabrica       38.736899
# 1874                                         Culturgest       38.740828
# 1879                 Casa-Museu Dr. Anastácio Gonçalves       38.732594
# 1892             Jardim da Fundação Calouste Gulbenkian       38.736794
# 1906                          Museu Calouste Gulbenkian       38.737812
# 1917             Jardim da Fundação Calouste Gulbenkian       38.736794
# 1923                       Fundação Calouste Gulbenkian       38.737431
# 1924                             Centro de Arte Moderna       38.735670
# 1925                          Museu Calouste Gulbenkian       38.737812
# 1943                            Jardim Amália Rodrigues       38.731144
# 1953  Anfiteatro ao Ar Livre: Fundação Calouste Gulb...       38.736245
# 1965                                        Estufa Fria       38.729629
# 1971                                 Parque Eduardo VII       38.728704
# 1973                    Miradouro do Parque Eduardo VII       38.730330
# 2009                                        Häagen-Dazs       38.732756
# 2016                                 Geladaria Artisani       38.760716
# 2023                               Museu Mundo Sporting       38.760821
# 2036                                    Museu de Lisboa       38.758836
# 2082                      Museu Rafael Bordalo Pinheiro       38.758865
# 2084                                   Jardim do Melkia       38.763798
# 2092                           Parque Prof Prado Coelho       38.765785
#
#       Venue Longitude         Venue Category Id    Venue Category
# 0           -9.134210  4bf58dd8d48988d1c9941735    Ice Cream Shop
# 2           -9.137231  4bf58dd8d48988d15a941735            Garden
# 6           -9.132833  4bf58dd8d48988d163941735              Park
# 11          -9.139545  4bf58dd8d48988d1c9941735    Ice Cream Shop
# 24          -9.142939  4bf58dd8d48988d1e2931735       Art Gallery
# 37          -9.137052  4bf58dd8d48988d1c9941735    Ice Cream Shop
# 51          -9.141959  4bf58dd8d48988d1c9941735    Ice Cream Shop
# 61          -9.142256  4bf58dd8d48988d15a941735            Garden
# 100         -9.142381  4bf58dd8d48988d1c9941735    Ice Cream Shop
# 143         -9.153823  4bf58dd8d48988d163941735              Park
# 200         -9.132833  4bf58dd8d48988d163941735              Park
# 217         -9.131145  4bf58dd8d48988d165941735    Scenic Lookout
# 226         -9.137231  4bf58dd8d48988d15a941735            Garden
# 234         -9.141959  4bf58dd8d48988d1c9941735    Ice Cream Shop
# 235         -9.137052  4bf58dd8d48988d1c9941735    Ice Cream Shop
# 238         -9.134210  4bf58dd8d48988d1c9941735    Ice Cream Shop
# 243         -9.142256  4bf58dd8d48988d15a941735            Garden
# 245         -9.142939  4bf58dd8d48988d1e2931735       Art Gallery
# 283         -9.137064  4bf58dd8d48988d15a941735            Garden
# 300         -9.132833  4bf58dd8d48988d163941735              Park
# 317         -9.131145  4bf58dd8d48988d165941735    Scenic Lookout
# 326         -9.137231  4bf58dd8d48988d15a941735            Garden
# 334         -9.141959  4bf58dd8d48988d1c9941735    Ice Cream Shop
# 335         -9.137052  4bf58dd8d48988d1c9941735    Ice Cream Shop
# 338         -9.134210  4bf58dd8d48988d1c9941735    Ice Cream Shop
# 343         -9.142256  4bf58dd8d48988d15a941735            Garden
# 345         -9.142939  4bf58dd8d48988d1e2931735       Art Gallery
# 383         -9.137064  4bf58dd8d48988d15a941735            Garden
# 401         -9.131500  4bf58dd8d48988d165941735    Scenic Lookout
# 419         -9.140521  4bf58dd8d48988d1c9941735    Ice Cream Shop
# ...               ...                       ...               ...
# 1741        -9.140773  4bf58dd8d48988d190941735    History Museum
# 1751        -9.140747  4bf58dd8d48988d1c9941735    Ice Cream Shop
# 1761        -9.133070  4bf58dd8d48988d165941735    Scenic Lookout
# 1769        -9.140544  4bf58dd8d48988d1c9941735    Ice Cream Shop
# 1774        -9.133103  50aaa49e4b90af0d42d5de11            Castle
# 1795        -9.136435  4bf58dd8d48988d1c9941735    Ice Cream Shop
# 1800        -9.144247  4bf58dd8d48988d165941735    Scenic Lookout
# 1805        -9.135339  4bf58dd8d48988d1c9941735    Ice Cream Shop
# 1834        -9.142256  4bf58dd8d48988d15a941735            Garden
# 1838        -9.141959  4bf58dd8d48988d1c9941735    Ice Cream Shop
# 1874        -9.142939  4bf58dd8d48988d1e2931735       Art Gallery
# 1879        -9.146419  4bf58dd8d48988d1e2931735       Art Gallery
# 1892        -9.153515  4bf58dd8d48988d166941735  Sculpture Garden
# 1906        -9.153749  4bf58dd8d48988d18f941735        Art Museum
# 1917        -9.153515  4bf58dd8d48988d166941735  Sculpture Garden
# 1923        -9.154540  4bf58dd8d48988d181941735            Museum
# 1924        -9.154153  4bf58dd8d48988d18f941735        Art Museum
# 1925        -9.153749  4bf58dd8d48988d18f941735        Art Museum
# 1943        -9.155050  4bf58dd8d48988d15a941735            Garden
# 1953        -9.153994  56aa371be4b08b9a8d5734db      Amphitheater
# 1965        -9.154989  4bf58dd8d48988d163941735              Park
# 1971        -9.153030  4bf58dd8d48988d163941735              Park
# 1973        -9.154410  4bf58dd8d48988d165941735    Scenic Lookout
# 2009        -9.152862  4bf58dd8d48988d1c9941735    Ice Cream Shop
# 2016        -9.168041  4bf58dd8d48988d1c9941735    Ice Cream Shop
# 2023        -9.160870  4bf58dd8d48988d190941735    History Museum
# 2036        -9.156223  4bf58dd8d48988d190941735    History Museum
# 2082        -9.154120  4bf58dd8d48988d18f941735        Art Museum
# 2084        -9.171710  4bf58dd8d48988d15a941735            Garden
# 2092        -9.171544  4bf58dd8d48988d163941735              Park
#
# [147 rows x 8 columns]

# %% [markdown]
# Let's see all the venues on a map:

# %%
# create map
map_lx = folium.Map(location=[lx_lat, lx_long], zoom_start=12)

# add markers to the map
for lat, lon, poi in zip(lx_venues_new['Venue Latitude'], lx_venues_new['Venue Longitude'],lx_venues_new['Venue'],):
    label = folium.Popup(str(poi) , parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='blue',
        fill_opacity=0.7).add_to(map_lx)

map_lx
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Please note that if the map is not visible, it can also be seen in https://github.com/AnaMariaAnaMaria/Coursera_Capstone/blob/master/LisbonVenues.JPG
